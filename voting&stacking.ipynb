# %% [markdown]
# ## Voting Classifier

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score , classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import BaggingClassifier

# %%
X , y = make_classification(
    n_samples = 500,
    n_features = 30,
    n_informative=10,
    n_redundant = 2,
    random_state=42
)

# %%
## Split our data
X_train , X_test , y_train ,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
lr = LogisticRegression()
svc = SVC()
knn = KNeighborsClassifier(n_neighbors=5)
tree = DecisionTreeClassifier(max_depth=3)
nb = GaussianNB()
bg_clf = BaggingClassifier(estimator = DecisionTreeClassifier(),n_estimators=10,random_state = 42)

# %%
voting_clf = VotingClassifier(
    estimators = [
        ("lr",lr),
        ("svc",svc),
        ("knn",knn),
        ("GaussianNB",nb),
        ("bg_clf",bg_clf)
    ],
    
)

# %%
voting_clf.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression()), ('svc', SVC()),
#                              ('knn', KNeighborsClassifier()),
#                              ('GaussianNB', GaussianNB()),
#                              ('bg_clf',
#                               BaggingClassifier(estimator=DecisionTreeClassifier(),
#                                                 random_state=42))])

# %%
predicted_val = voting_clf.predict(X_test)

# %%
print("Accuracy_score:",accuracy_score(predicted_val,y_test))
# Out:
# Accuracy_score: 0.8666666666666667

# %% [markdown]
# ## Voting Regressor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import BaggingRegressor
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import VotingRegressor

# %%
X , y = make_regression(
    n_samples = 500,
    n_features = 30,
    n_informative=10,
    random_state=42
)

# %%
X_train , X_test , y_train ,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
lr = LinearRegression()
svr = SVR()
knn = KNeighborsRegressor(n_neighbors=5)
bg_reg = BaggingRegressor(estimator = DecisionTreeRegressor(),n_estimators=10,random_state = 42)
dtr = DecisionTreeRegressor(max_depth=3)

# %%
voting_reg.fit(X_train,y_train)
# Out:
# VotingRegressor(estimators=[('lr', LinearRegression()), ('svr', SVR()),
#                             ('bg_reg',
#                              BaggingRegressor(estimator=DecisionTreeRegressor(),
#                                               random_state=42))])

# %%
predicted_val = voting_reg.predict(X_test)

# %%
from sklearn.metrics import r2_score
print("r2_score:",r2_score(y_test,predicted_val))
# Out:
# r2_score: 0.7587185733149026

# %% [markdown]
# ## Stacking Classifier

# %%
from sklearn.ensemble import StackingClassifier

# %%
X , y = make_classification(
    n_samples = 500,
    n_features = 30,
    n_informative=10,
    n_redundant = 2,
    random_state=42
)

# %%
X_train , X_test , y_train ,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
lr = LogisticRegression()
svc = SVC()
knn = KNeighborsClassifier(n_neighbors=5)
tree = DecisionTreeClassifier(max_depth=3)
nb = GaussianNB()
bg_clf = BaggingClassifier(estimator = DecisionTreeClassifier(),n_estimators=10,random_state = 42)

# %%
stacking_clf = StackingClassifier(
    estimators = [
        ("lr",lr),
        ("svc",svc),
        ("knn",knn),
        ("GaussianNB",nb),
        ("bg_clf",bg_clf)
    ],
    cv=5
)

# %%
stacking_clf.fit(X_train,y_train)
# Out:
# StackingClassifier(cv=5,
#                    estimators=[('lr', LogisticRegression()), ('svc', SVC()),
#                                ('knn', KNeighborsClassifier()),
#                                ('GaussianNB', GaussianNB()),
#                                ('bg_clf',
#                                 BaggingClassifier(estimator=DecisionTreeClassifier(),
#                                                   random_state=42))])

# %%
y_pred = stacking_clf.predict(X_test)

# %%
print("Accuracy_score:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy_score: 0.9266666666666666

# %% [markdown]
# ## Stacking Regressor

# %%
from sklearn.ensemble import StackingRegressor

# %%
lr = LinearRegression()
svr = SVR()
knn = KNeighborsRegressor(n_neighbors=5)
bg_reg = BaggingRegressor(estimator = DecisionTreeRegressor(),n_estimators=10,random_state = 42)
dtr = DecisionTreeRegressor(max_depth=3)

# %%
stacking_reg = StackingRegressor(
    estimators=[
        ("svr",svr),
        ("dtr",dtr),
        ("lr",lr),
        ("knn",knn)
    ],
    cv=5
)

# %%
stacking_reg.fit(X_train,y_train)
# Out:
# StackingRegressor(cv=5,
#                   estimators=[('svr', SVR()),
#                               ('dtr', DecisionTreeRegressor(max_depth=3)),
#                               ('lr', LinearRegression()),
#                               ('knn', KNeighborsRegressor())])

# %%
y_pred = stacking_reg.predict(X_test)

# %%
print("r2_score:",r2_score(y_test,y_pred))
# Out:
# r2_score: 0.9999999999999996
